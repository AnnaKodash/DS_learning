# %%
import pandas as pd

# %%
melb_data = pd.read_csv('data\melb_data_ps.csv')
display(melb_data.head())
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...    1     202.0         126.0       1970
# 1  4/02/2016       2.5  ...    0     156.0          79.0       1900
# 2  4/03/2017       2.5  ...    0     134.0         150.0       1900
# 3  4/03/2017       2.5  ...    1      94.0         126.0       1970
# 4  4/06/2016       2.5  ...    2     120.0         142.0       2014
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# ...

# %%
melb_df = melb_data.copy()

# %%
melb_df = melb_df.drop(['index', 'Coordinates'], axis=1)

# %%
melb_df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5      3067  ...         1    1     202.0         126.0
# 1  4/02/2016       2.5      3067  ...         1    0     156.0          79.0
# 2  4/03/2017       2.5      3067  ...         2    0     134.0         150.0
# 3  4/03/2017       2.5      3067  ...         2    1      94.0         126.0
# 4  4/06/2016       2.5      3067  ...         1    2     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
total_rooms = melb_df['Rooms'] + melb_df['Bedroom'] + melb_df['Bathroom']
melb_df['MeanRoomsSquare'] = melb_df['BuildingArea']/total_rooms
melb_df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5      3067  ...    1     202.0         126.0       1970
# 1  4/02/2016       2.5      3067  ...    0     156.0          79.0       1900
# 2  4/03/2017       2.5      3067  ...    0     134.0         150.0       1900
# 3  4/03/2017       2.5      3067  ...    1      94.0         126.0       1970
# 4  4/06/2016       2.5      3067  ...    2     120.0         142.0       2014
#
# ...

# %%
diff_area = melb_df['BuildingArea'] - melb_df['Landsize']
sum_area = melb_df['BuildingArea'] + melb_df['Landsize']
melb_df['AlterRatio'] = diff_area/sum_area
melb_df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5      3067  ...     202.0         126.0       1970
# 1  4/02/2016       2.5      3067  ...     156.0          79.0       1900
# 2  4/03/2017       2.5      3067  ...     134.0         150.0       1900
# 3  4/03/2017       2.5      3067  ...      94.0         126.0       1970
# 4  4/06/2016       2.5      3067  ...     120.0         142.0       2014
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# ...

# %%
melb_df['Date'] = pd.to_datetime(melb_df['Date'], dayfirst=True)

# %%
melb_df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Landsize  BuildingArea  YearBuilt  \
# 0 2016-12-03       2.5      3067  ...     202.0         126.0       1970
# 1 2016-02-04       2.5      3067  ...     156.0          79.0       1900
# 2 2017-03-04       2.5      3067  ...     134.0         150.0       1900
# 3 2017-03-04       2.5      3067  ...      94.0         126.0       1970
# 4 2016-06-04       2.5      3067  ...     120.0         142.0       2014
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# ...

# %%
years_sold = melb_df['Date'].dt.year

# %%
print(years_sold.min())
print(years_sold.max())
print(years_sold.mode()[0])
# Out:
# 2016
# 2017
# 2017

# %%
melb_df['MonthSale'] = melb_df['Date'].dt.month
melb_df['MonthSale'].value_counts(normalize=True)
# Out:
# 5     0.149411
# 7     0.145950
# 9     0.135862
# 6     0.134757
# 8     0.114138
# 11    0.082032
# 4     0.069882
# 3     0.049926
# 12    0.044698
# 10    0.040574
# 2     0.032622
# 1     0.000147
# Name: MonthSale, dtype: float64

# %%
delta_days = melb_df['Date'] - pd.to_datetime('2016-01-01')

# %%
display(delta_days.head())
# Out:
# 0   337 days
# 1    34 days
# 2   428 days
# 3   428 days
# 4   155 days
# Name: Date, dtype: timedelta64[ns]

# %%
display(delta_days.dt.days)
# Out:
# 0        337
# 1         34
# 2        428
# 3        428
# 4        155
#         ...
# 13575    603
# 13576    603
# 13577    603
# 13578    603
# 13579    603
# Name: Date, Length: 13580, dtype: int64

# %%
melb_df['AgeBuilding'] = melb_df['Date'].dt.year - melb_df['YearBuilt']
melb_df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  YearBuilt  CouncilArea  Lattitude  \
# 0 2016-12-03       2.5      3067  ...       1970        Yarra   -37.7996
# 1 2016-02-04       2.5      3067  ...       1900        Yarra   -37.8079
# 2 2017-03-04       2.5      3067  ...       1900        Yarra   -37.8093
# 3 2017-03-04       2.5      3067  ...       1970        Yarra   -37.7969
# 4 2016-06-04       2.5      3067  ...       2014        Yarra   -37.8072
#
#    Longtitude             Regionname  Propertycount MeanRoomsSquare  \
# ...

# %%
melb_df = melb_df.drop(['YearBuilt'], axis=1)

# %%
melb_df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  BuildingArea  CouncilArea  Lattitude  \
# 0 2016-12-03       2.5      3067  ...         126.0        Yarra   -37.7996
# 1 2016-02-04       2.5      3067  ...          79.0        Yarra   -37.8079
# 2 2017-03-04       2.5      3067  ...         150.0        Yarra   -37.8093
# 3 2017-03-04       2.5      3067  ...         126.0        Yarra   -37.7969
# 4 2016-06-04       2.5      3067  ...         142.0        Yarra   -37.8072
#
#    Longtitude             Regionname Propertycount  MeanRoomsSquare  \
# ...

# %%
melb_df['WeekdaySale'] = melb_df['Date'].dt.dayofweek

# %%
melb_df['WeekdaySale'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        5
# 1        3
# 2        5
# 3        5
# 4        5
#         ..
# 13575    5
# 13576    5
# 13577    5
# 13578    5
# 13579    5
# Name: WeekdaySale, Length: 13580, dtype: int64>

# %%
weekend_count = melb_df[(melb_df['WeekdaySale']== 5) | (melb_df['WeekdaySale']== 6)].shape[0]

# %%
print(weekend_count)
# Out:
# 12822

# %%
melb_df['WeekdaySale'].describe()
# Out:
# count    13580.000000
# mean         4.815169
# std          1.143767
# min          0.000000
# 25%          5.000000
# 50%          5.000000
# 75%          5.000000
# max          6.000000
# Name: WeekdaySale, dtype: float64

# %%
melb_df['Address'].nunique()
# Out:
# 13378

# %%
def get_street_type(address):
    exclude_list = ['N','S','W','E']
    address_list = address.split(' ')
    street_type = address_list[-1]
    if street_type in exclude_list:
        street_type = address_list[-2]
    return street_type

# %%
street_types = melb_df['Address'].apply(get_street_type)
display(street_types)
# Out:
# 0        St
# 1        St
# 2        St
# 3        La
# 4        St
#          ..
# 13575    Cr
# 13576    Dr
# 13577    St
# 13578    St
# 13579    St
# Name: Address, Length: 13580, dtype: object

# %%
street_types.nunique()
# Out:
# 56

# %%
melb_df['street_types'] = melb_df['Address'].apply(get_street_type)
melb_df = melb_df.drop(['street_types'], axis=1)

# %%
melb_df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  CouncilArea  Lattitude  Longtitude  \
# 0 2016-12-03       2.5      3067  ...        Yarra   -37.7996    144.9984
# 1 2016-02-04       2.5      3067  ...        Yarra   -37.8079    144.9934
# 2 2017-03-04       2.5      3067  ...        Yarra   -37.8093    144.9944
# 3 2017-03-04       2.5      3067  ...        Yarra   -37.7969    144.9969
# 4 2016-06-04       2.5      3067  ...        Yarra   -37.8072    144.9941
#
#               Regionname  Propertycount MeanRoomsSquare  AlterRatio  \
# ...

# %%
street_types.value_counts()
# Out:
# St           8012
# Rd           2825
# Ct            612
# Dr            447
# Av            321
# Gr            311
# Pde           211
# Pl            169
# Cr            152
# Cl            100
# La             67
# Bvd            53
# Tce            47
# Wy             40
# Avenue         40
# Cct            25
# Hwy            24
# Parade         15
# Boulevard      13
# Sq             11
# Crescent        9
# Cir             7
# Strand          7
# Esplanade       6
# Grove           5
# Gdns            4
# Grn             4
# Fairway         4
# Mews            4
# Crossway        3
# Righi           3
# Victoria        2
# Ridge           2
# Crofts          2
# Esp             2
# Glade           1
# Gra             1
# Ave             1
# Woodland        1
# Outlook         1
# Hts             1
# Highway         1
# Athol           1
# Summit          1
# Grand           1
# Res             1
# Nook            1
# Eyrie           1
# Dell            1
# East            1
# ...

# %%
popular_stypes = street_types.value_counts().nlargest(10).index

# %%
popular_stypes
# Out:
# Index(['St', 'Rd', 'Ct', 'Dr', 'Av', 'Gr', 'Pde', 'Pl', 'Cr', 'Cl'], dtype='object')

# %%
melb_df['StreetType'] = street_types.apply(lambda x: x if x in popular_stypes else 'other')
display(melb_df['StreetType'])
# Out:
# 0           St
# 1           St
# 2           St
# 3        other
# 4           St
#          ...
# 13575       Cr
# 13576       Dr
# 13577       St
# 13578       St
# 13579       St
# Name: StreetType, Length: 13580, dtype: object

# %%
melb_df = melb_df.drop(['Address'], axis=1)

# %%
melb_df.head()
# Out:
#        Suburb  Rooms Type      Price Method SellerG       Date  Distance  \
# 0  Abbotsford      2    h  1480000.0      S  Biggin 2016-12-03       2.5
# 1  Abbotsford      2    h  1035000.0      S  Biggin 2016-02-04       2.5
# 2  Abbotsford      3    h  1465000.0     SP  Biggin 2017-03-04       2.5
# 3  Abbotsford      3    h   850000.0     PI  Biggin 2017-03-04       2.5
# 4  Abbotsford      4    h  1600000.0     VB  Nelson 2016-06-04       2.5
#
#    Postcode  Bedroom  ...  Lattitude  Longtitude             Regionname  \
# 0      3067        2  ...   -37.7996    144.9984  Northern Metropolitan
# 1      3067        2  ...   -37.8079    144.9934  Northern Metropolitan
# 2      3067        3  ...   -37.8093    144.9944  Northern Metropolitan
# 3      3067        3  ...   -37.7969    144.9969  Northern Metropolitan
# 4      3067        3  ...   -37.8072    144.9941  Northern Metropolitan
#
#    Propertycount MeanRoomsSquare  AlterRatio  MonthSale AgeBuilding  \
# ...

# %%
def get_weekend(weekday):
    if weekday in [0, 1, 2, 3, 4]:
        return 0
    else:
        return 1
    
    
melb_df['Weekend'] = melb_df['WeekdaySale'].apply(get_weekend)
display(melb_df.head())
# Out:
#        Suburb  Rooms Type      Price Method SellerG       Date  Distance  \
# 0  Abbotsford      2    h  1480000.0      S  Biggin 2016-12-03       2.5
# 1  Abbotsford      2    h  1035000.0      S  Biggin 2016-02-04       2.5
# 2  Abbotsford      3    h  1465000.0     SP  Biggin 2017-03-04       2.5
# 3  Abbotsford      3    h   850000.0     PI  Biggin 2017-03-04       2.5
# 4  Abbotsford      4    h  1600000.0     VB  Nelson 2016-06-04       2.5
#
#    Postcode  Bedroom  ...  Longtitude             Regionname  Propertycount  \
# 0      3067        2  ...    144.9984  Northern Metropolitan           4019
# 1      3067        2  ...    144.9934  Northern Metropolitan           4019
# 2      3067        3  ...    144.9944  Northern Metropolitan           4019
# 3      3067        3  ...    144.9969  Northern Metropolitan           4019
# 4      3067        3  ...    144.9941  Northern Metropolitan           4019
#
# ...

# %%
melb_df[melb_df['Weekend']==1]['Price'].mean()
# Out:
# 1081198.6406956792

# %%
popular_rlt = melb_df['SellerG'].value_counts().nlargest(49)

# %%
melb_df['SellerG'] = melb_df['SellerG'].apply(lambda x: x if x in popular_rlt else 'other')

# %%
melb_df['SellerG'].value_counts()
# Out:
# Nelson           1565
# Jellis           1316
# other            1199
# hockingstuart    1167
# Barry            1011
# Ray               701
# Marshall          659
# Buxton            632
# Biggin            393
# Brad              342
# Woodards          301
# Fletchers         301
# Jas               243
# Greg              239
# McGrath           222
# Sweeney           216
# Noel              205
# Miles             196
# RT                184
# Gary              170
# Harcourts         168
# Hodges            157
# YPA               154
# Stockdale         150
# Village           125
# Kay               119
# Raine             116
# Williams          111
# Love              109
# Douglas            97
# Chisholm           77
# RW                 70
# Rendina            66
# HAR                62
# O'Brien            61
# C21                57
# Collins            56
# Cayzer             52
# Eview              51
# Purplebricks       51
# Philip             48
# ...

# %%
result = melb_df[melb_df['SellerG']=='Nelson']['Price'].min()/melb_df[melb_df['SellerG']=='other']['Price'].min()

# %%
result
# Out:
# 1.297709923664122

# %%
unique_list = []
for col in melb_df.columns:
    item = (col, melb_df[col].nunique(), melb_df[col].dtype)
    unique_list.append(item)
unique_counts = pd.DataFrame(unique_list, columns=['Column_Nmae', 'Num_Unique', 'Type']).sort_values(by='Num_Unique', ignore_index=True)
display(unique_counts)
# Out:
#         Column_Nmae  Num_Unique            Type
# 0           Weekend           2           int64
# 1              Type           3          object
# 2            Method           5          object
# 3       WeekdaySale           5           int64
# 4        Regionname           8          object
# 5          Bathroom           9           int64
# 6             Rooms           9           int64
# 7               Car          11           int64
# 8        StreetType          11          object
# 9           Bedroom          12           int64
# 10        MonthSale          12           int64
# 11      CouncilArea          33          object
# 12          SellerG          50          object
# 13             Date          58  datetime64[ns]
# 14      AgeBuilding         152           int64
# 15         Postcode         198           int64
# 16         Distance         202         float64
# 17    Propertycount         311           int64
# 18           Suburb         314          object
# ...

# %%
cols_to_exclude = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car']
max_unique_count = 150
for col in melb_df.columns:
    if (melb_df[col].nunique() < max_unique_count) and (col not in cols_to_exclude):
        melb_df[col] = melb_df[col].astype('category')

# %%
print(melb_df['Regionname'].cat.categories)
# Out:
# Index(['Eastern Metropolitan', 'Eastern Victoria', 'Northern Metropolitan',
#        'Northern Victoria', 'South-Eastern Metropolitan',
#        'Southern Metropolitan', 'Western Metropolitan', 'Western Victoria'],
#       dtype='object')

# %%
melb_df['Type'] = melb_df['Type'].cat.rename_categories({
    'u': 'unit',
    't': 'townhouse',
    'h': 'house'
})

# %%
melb_df
# Out:
#               Suburb  Rooms   Type      Price Method   SellerG       Date  \
# 0         Abbotsford      2  house  1480000.0      S    Biggin 2016-12-03
# 1         Abbotsford      2  house  1035000.0      S    Biggin 2016-02-04
# 2         Abbotsford      3  house  1465000.0     SP    Biggin 2017-03-04
# 3         Abbotsford      3  house   850000.0     PI    Biggin 2017-03-04
# 4         Abbotsford      4  house  1600000.0     VB    Nelson 2016-06-04
# ...              ...    ...    ...        ...    ...       ...        ...
# 13575  Wheelers Hill      4  house  1245000.0      S     Barry 2017-08-26
# 13576   Williamstown      3  house  1031000.0     SP  Williams 2017-08-26
# 13577   Williamstown      3  house  1170000.0      S     Raine 2017-08-26
# 13578   Williamstown      4  house  2500000.0     PI   Sweeney 2017-08-26
# 13579     Yarraville      4  house  1285000.0     SP   Village 2017-08-26
#
#        Distance  Postcode  Bedroom  ...  Longtitude  \
# ...

# %%
melb_df['Type'] = melb_df['Type'].cat.add_categories('flat')
new_houses_types = pd.Series(['unit', 'house', 'flat', 'flat', 'house'])
new_houses_types = new_houses_types.astype(melb_df['Type'].dtype)
display(new_houses_types)
# Out:
# 0     unit
# 1    house
# 2     flat
# 3     flat
# 4    house
# dtype: category
# Categories (4, object): ['house', 'townhouse', 'unit', 'flat']

# %%
melb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  object
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  category
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  category
#  5   SellerG          13580 non-null  category
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  category
#  15  Lattitude        13580 non-null  float64
# ...

# %%
subur = melb_df['Suburb'].value_counts().nlargest(119)
melb_df['Suburb'] = melb_df['Suburb'].apply(lambda x: x if x in subur else 'other')
melb_df['Suburb'] = melb_df['Suburb'].astype('category')
melb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  category
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  category
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  category
#  5   SellerG          13580 non-null  category
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  category
#  15  Lattitude        13580 non-null  float64
# ...
